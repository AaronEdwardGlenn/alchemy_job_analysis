# %%
import pandas as pd

# %%
df = pd.read_csv('glassdoor.csv')

# %%
df
# Out:
#      Unnamed: 0                                      Job Title  \
# 0             0                             Software Developer
# 1             1                             Software Developer
# 2             2                                  App Developer
# 3             3                         Lead Software Engineer
# 4             4                              Software Engineer
# ..          ...                                            ...
# 260         260                              Software Engineer
# 261         261                           Automation Developer
# 262         262                        UI/UX Software Engineer
# 263         263  Senior Software Analyst - relocation required
# 264         264             MTS Software Engineer, Data Infra.
#
#                  Salary Estimate  \
# 0     $52K-$94K (Glassdoor est.)
# 1     $52K-$94K (Glassdoor est.)
# 2     $52K-$94K (Glassdoor est.)
# 3     $52K-$94K (Glassdoor est.)
# 4     $52K-$94K (Glassdoor est.)
# ...
